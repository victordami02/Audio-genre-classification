# %% [markdown]
# # GENRE CLASSIFICATION EDA, Processing, Modeling & Recommend
#
# ## Audio classification is an Application of machine learning where different sound is categorized in certain categories.
# -  In this project, we will build a complete music Genre classification project from scratch using a machine learning algorithm,Performed EDA, Feature engineering and a recommender system for the genre classification.

# %%
pwd
# Out:
# '/Users/mac/Documents'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# Librosa (the mother of audio files)
import librosa
import librosa.display
import IPython.display as ipd
import warnings
warnings.filterwarnings('ignore')

# %%
# pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 322.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: decorator>=4.3.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: joblib>=0.14 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.2.0)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp39-cp39-macosx_10_9_x86_64.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 295.7 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: msgpack>=1.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: numba>=0.51.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.21.5)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 584.1 kB/s eta 0:00:0000:0100:01
# Collecting pooch<1.7,>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 746.5 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: scipy>=1.2.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.9.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from librosa) (4.3.0)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 864.8 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.4)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23703 sha256=592967cab610faa9d9b52318f3f077d6c94a59d5bdb44ce3173c0ac54834d16a
#   Stored in directory: /Users/mac/Library/Caches/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# Installing collected packages: soxr, lazy-loader, audioread, soundfile, pooch, librosa
# Successfully installed audioread-3.0.0 lazy-loader-0.2 librosa-0.10.0.post2 pooch-1.6.0 soundfile-0.12.1 soxr-0.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# read the dataset
import os
general_path = '/Users/mac/Documents/Data'
print(list(os.listdir(f'{general_path}/genres_original/')))
# Out:
# ['pop', '.DS_Store', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock', 'hiphop', 'country', 'jazz']

# %% [markdown]
# # Explore Audio Data using librosa
# - librosa is a python package for music and audio analysis. It provides the building blocks necessary to create music information retrieval systems.

# %%
# using an example of the audio file
y, sr = librosa.load(f'{general_path}/genres_original/blues/blues.00023.wav')

print('y:', y, '\n')
print('y shape:', np.shape(y), '\n')
print('Sample Rate (KHz):', sr, '\n')
# Out:
# y: [ 0.17184448  0.20730591  0.08227539 ...  0.00271606 -0.02062988
#  -0.01370239]
#
# y shape: (661794,)
#
# Sample Rate (KHz): 22050

# %%
# Trim leading and trailing silence from an audio signal (silence before and after the actual audio)
audio, _ = librosa.effects.trim(y)

print('Audio File:', audio, '\n')
print('Audio File shape:', np.shape(audio))
# Out:
# Audio File: [ 0.034729    0.07818604  0.0899353  ... -0.17190552 -0.19494629
#  -0.19726562]
#
# Audio File shape: (661504,)

# %%
# EDA

# %%
import librosa.display
plt.figure(figsize = (16, 6))
librosa.display.waveshow(y = audio, sr = sr, color = "#00008B");
plt.title("sound waves on blues", fontsize = 20);

# %%
# Fourier Transform
n_fft = 2048 # default fft window size
hop_length = 512 

# short-time fourier transform (stft)
stft = np.abs(librosa.stft(audio, n_fft = n_fft, hop_length = hop_length))

print('Shape of stft:', np.shape(stft))
# Out:
# Shape of stft: (1025, 1293)

# %%
plt.figure(figsize = (16, 6))
plt.plot(stft);

# %% [markdown]
# # The spectrogram
# - A spectrogram is a visual representation of the spectrum of frequencies of a signal as it varies with time. When applied to an audio signal, spectrograms are sometimes called sonographs, voiceprints, or voicegrams (wiki).

# %%
# Convert an amplitude spectrogram to Decibels-scaled spectrogram.
DB = librosa.amplitude_to_db(stft, ref = np.max)

# Creating the Spectogram
plt.figure(figsize = (16, 6))
librosa.display.specshow(DB, sr = sr, hop_length = hop_length, x_axis = 'time', y_axis = 'log',
                        cmap = 'cool')
plt.colorbar();

# %% [markdown]
# # Audio features

# %%
# Total zero_crossings in our 1 song
zero_crossings = librosa.zero_crossings(audio, pad=False)
print(sum(zero_crossings))
# Out:
# 34769

# %% [markdown]
# # Harmonics and Perceptrual

# %%
y_harm, y_perc = librosa.effects.hpss(audio)

# %%
y_harm
# Out:
# array([ 0.05860212,  0.07427445,  0.04690354, ...,  0.00548941,
#        -0.00852439, -0.00431491], dtype=float32)

# %%
plt.figure(figsize=(16,6))
plt.plot(y_harm, color = '#028A0F');
plt.plot(y_perc, color = '#FFB100');

# %% [markdown]
# # Spectral Centroid

# %%
def spectral_centroid(audio, samplerate=sr):
    magnitudes = np.abs(np.fft.rfft(audio)) # magnitudes of positive frequencies
    length = len(audio)
    freqs = np.abs(np.fft.fftfreq(length, 1.0/samplerate)[:length//2+1]) # positive frequencies
    return np.sum(magnitudes*freqs) / np.sum(magnitudes) # return weighted mean

# %%
sc = spectral_centroid(audio, sr)

# %% [markdown]
# # Mel-Frequency Cepstral Coefficients:
# - The Mel frequency cepstral coefficients (MFCCs) of a signal are a small set of features (usually about 10–20) which concisely describe the overall shape of a spectral envelope. It models the characteristics of the human voice.

# %%
mfcc = librosa.feature.mfcc(y=audio, sr=sr)

# %%
print('mfcc shape:', mfcc.shape)

plt.figure(figsize = (16, 6))
librosa.display.specshow(mfcc, sr=sr, x_axis='time', cmap = 'cool');
# Out:
# mfcc shape: (20, 1293)

# %%
mfcc = sklearn.preprocessing.scale(mfcc, axis=1)
print('Mean:', mfcc.mean(), '\n')
print('Var:', mfcc.var())

plt.figure(figsize = (16, 6))
librosa.display.specshow(mfcc, sr=sr, x_axis='time', cmap = 'bwr');
# Out:
# Mean: -1.4751342e-09
#
# Var: 1.0000001

# %% [markdown]
# # EDA on the audio genre label dataset

# %%
df = pd.read_csv(f'{general_path}/features_30_sec.csv')
df.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# 1              2039.036516           213843.755497  ...   55.356403
# 2              1747.702312            76254.192257  ...   40.598766
# 3              1596.412872           166441.494769  ...   44.427753
# 4              1748.172116            88445.209036  ...   86.099236
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -1.690215   36.524071    -0.408979   41.597103    -2.303523   55.062923
# 1    -0.731125   60.314529     0.295073   48.120598    -0.283518   51.106190
# 2    -7.729093   47.639427    -1.816407   52.382141    -3.439720   46.639660
# 3    -3.319597   50.206673     0.636965   37.319130    -0.619121   37.259739
# 4    -5.454034   75.269707    -0.916874   53.613918    -4.404827   62.910812
#
#    mfcc20_mean  mfcc20_var  label
# 0     1.221291   46.936035  blues
# 1     0.531217   45.786282  blues
# 2    -2.231258   30.573025  blues
# 3    -3.407448   31.949339  blues
# 4   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %%
# This file contains the mean and variance for each audio file for the features analysed above.


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 60 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   filename                 1000 non-null   object
#  1   length                   1000 non-null   int64
#  2   chroma_stft_mean         1000 non-null   float64
#  3   chroma_stft_var          1000 non-null   float64
#  4   rms_mean                 1000 non-null   float64
#  5   rms_var                  1000 non-null   float64
#  6   spectral_centroid_mean   1000 non-null   float64
#  7   spectral_centroid_var    1000 non-null   float64
#  8   spectral_bandwidth_mean  1000 non-null   float64
#  9   spectral_bandwidth_var   1000 non-null   float64
#  10  rolloff_mean             1000 non-null   float64
#  11  rolloff_var              1000 non-null   float64
#  12  zero_crossing_rate_mean  1000 non-null   float64
#  13  zero_crossing_rate_var   1000 non-null   float64
#  14  harmony_mean             1000 non-null   float64
#  15  harmony_var              1000 non-null   float64
#  16  perceptr_mean            1000 non-null   float64
#  17  perceptr_var             1000 non-null   float64
#  18  tempo                    1000 non-null   float64
#  19  mfcc1_mean               1000 non-null   float64
#  20  mfcc1_var                1000 non-null   float64
#  21  mfcc2_mean               1000 non-null   float64
#  22  mfcc2_var                1000 non-null   float64
#  23  mfcc3_mean               1000 non-null   float64
#  24  mfcc3_var                1000 non-null   float64
#  25  mfcc4_mean               1000 non-null   float64
#  26  mfcc4_var                1000 non-null   float64
#  27  mfcc5_mean               1000 non-null   float64
#  28  mfcc5_var                1000 non-null   float64
#  29  mfcc6_mean               1000 non-null   float64
#  30  mfcc6_var                1000 non-null   float64
#  31  mfcc7_mean               1000 non-null   float64
#  32  mfcc7_var                1000 non-null   float64
#  33  mfcc8_mean               1000 non-null   float64
#  34  mfcc8_var                1000 non-null   float64
#  35  mfcc9_mean               1000 non-null   float64
#  36  mfcc9_var                1000 non-null   float64
#  37  mfcc10_mean              1000 non-null   float64
#  38  mfcc10_var               1000 non-null   float64
#  39  mfcc11_mean              1000 non-null   float64
#  40  mfcc11_var               1000 non-null   float64
#  41  mfcc12_mean              1000 non-null   float64
#  42  mfcc12_var               1000 non-null   float64
#  43  mfcc13_mean              1000 non-null   float64
#  44  mfcc13_var               1000 non-null   float64
#  45  mfcc14_mean              1000 non-null   float64
#  46  mfcc14_var               1000 non-null   float64
#  47  mfcc15_mean              1000 non-null   float64
#  48  mfcc15_var               1000 non-null   float64
#  49  mfcc16_mean              1000 non-null   float64
#  50  mfcc16_var               1000 non-null   float64
#  51  mfcc17_mean              1000 non-null   float64
#  52  mfcc17_var               1000 non-null   float64
#  53  mfcc18_mean              1000 non-null   float64
#  54  mfcc18_var               1000 non-null   float64
#  55  mfcc19_mean              1000 non-null   float64
#  56  mfcc19_var               1000 non-null   float64
#  57  mfcc20_mean              1000 non-null   float64
#  58  mfcc20_var               1000 non-null   float64
#  59  label                    1000 non-null   object
# dtypes: float64(57), int64(1), object(2)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#               length  chroma_stft_mean  chroma_stft_var     rms_mean  \
# count    1000.000000       1000.000000      1000.000000  1000.000000
# mean   662030.846000          0.378682         0.086340     0.130930
# std      1784.073992          0.081705         0.007735     0.065683
# min    660000.000000          0.171939         0.044555     0.005276
# 25%    661504.000000          0.319562         0.082298     0.086657
# 50%    661794.000000          0.383148         0.086615     0.122443
# 75%    661794.000000          0.435942         0.091256     0.175682
# max    675808.000000          0.663685         0.108111     0.397973
#
#            rms_var  spectral_centroid_mean  spectral_centroid_var  \
# count  1000.000000             1000.000000           1.000000e+03
# mean      0.003051             2201.780898           4.696916e+05
# std       0.003634              715.960600           4.008995e+05
# min       0.000004              570.040355           7.911251e+03
# 25%       0.000942             1627.697311           1.843505e+05
# 50%       0.001816             2209.263090           3.384862e+05
# 75%       0.003577             2691.294667           6.121479e+05
# max       0.027679             4435.243901           3.036843e+06
#
#        spectral_bandwidth_mean  spectral_bandwidth_var  rolloff_mean  ...  \
# count              1000.000000             1000.000000   1000.000000  ...
# mean               2242.541070           137079.155165   4571.549304  ...
# std                 526.316473            96455.666326   1574.791602  ...
# min                 898.066208            10787.185064    749.140636  ...
# 25%                1907.240605            67376.554428   3380.069642  ...
# 50%                2221.392843           111977.548036   4658.524473  ...
# 75%                2578.469836           182371.576801   5533.810460  ...
# max                3509.646417           694784.811549   8677.672688  ...
#
#        mfcc16_mean   mfcc16_var  mfcc17_mean   mfcc17_var  mfcc18_mean  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.148144    60.730958    -3.966028    62.633624     0.507696
# std       4.578948    33.781951     4.549697    33.479172     3.869105
# min     -15.693844     9.169314   -17.234728    13.931521   -11.963694
# 25%      -1.863280    40.376442    -7.207225    40.830875    -2.007015
# 50%       1.212809    52.325077    -4.065605    54.717674     0.669643
# 75%       4.359662    71.691755    -0.838737    75.040838     3.119212
# max      13.457150   392.932373    11.482946   406.058868    15.388390
#
#         mfcc18_var  mfcc19_mean   mfcc19_var  mfcc20_mean   mfcc20_var
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     63.712586    -2.328761    66.231930    -1.095348    70.126096
# std      34.401977     3.755957    37.174631     3.837007    45.228512
# min      15.420555   -18.501955    13.487622   -19.929634     7.956583
# 25%      41.884240    -4.662925    41.710184    -3.368996    42.372865
# 50%      54.804890    -2.393862    57.423059    -1.166289    59.186117
# 75%      75.385832     0.150573    78.626444     1.312615    85.375374
# max     332.905426    14.694924   393.161987    15.369627   506.065155
#
# [8 rows x 58 columns]

# %%
corr = df.corr()

# %%
sns.heatmap(corr, cmap="bwr", vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Box Plot for Genres Distributions

# %%
x = df[['label', 'tempo']]

f, ax = plt.subplots(figsize=(16,9));
sns.boxplot(x = 'label', y = 'tempo', data = x, palette = 'summer');

plt.title('BPM Boxplot for Genres', fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("BPM", fontsize = 15)
# Out:
# Text(0, 0.5, 'BPM')

# %% [markdown]
# # scaling the data for PCA
# - The Principal Component Analysis is a popular unsupervised learning technique for reducing the dimensionality of data. It increases interpretability yet, at the same time, it minimizes information loss. It helps to find the most significant features in a dataset and makes the data easy for plotting in 2D and 3D.

# %%
from sklearn import preprocessing

df = df.iloc[0:, 1:]
y = df['label']
X = df.loc[:, df.columns != 'label']

cols = X.columns
scaler = preprocessing.MinMaxScaler()
np_scaled = scaler.fit_transform(X)
X = pd.DataFrame(np_scaled, columns = cols)

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
scaled_df = pca.fit_transform(X)
df_p = pd.DataFrame(data = scaled_df, columns = ['pca1', 'pca2'])

fdf = pd.concat([df_p, y], axis = 1)

pca.explained_variance_ratio_
# Out:
# array([0.2523914 , 0.20972602])

# %%
plt.figure(figsize=(16,9), dpi=150)
sns.scatterplot(x = "pca1", y = "pca2", data = fdf, hue = "label", alpha = 0.7,
               s = 100);

plt.title('Genres with PCa', fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Principal Component 1", fontsize = 15)
plt.ylabel("Principal Component 2", fontsize = 15)
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %% [markdown]
# # Machine Learning Classification
# - Using the features_3_sec.csv file, we can try to build a classifier that accurately predicts for any new audio file input it's genre.

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from xgboost import plot_tree, plot_importance

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
# read in the data
df = pd.read_csv(f'{general_path}/features_3_sec.csv')
df = df.iloc[0:,1:]
df.head()
# Out:
#    length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0   66149          0.335406         0.091048  0.130405  0.003521
# 1   66149          0.343065         0.086147  0.112699  0.001450
# 2   66149          0.346815         0.092243  0.132003  0.004620
# 3   66149          0.363639         0.086856  0.132565  0.002448
# 4   66149          0.335579         0.088129  0.143289  0.001701
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1773.065032          167541.630869              1972.744388
# 1             1816.693777           90525.690866              2010.051501
# 2             1788.539719          111407.437613              2084.565132
# 3             1655.289045          111952.284517              1960.039988
# 4             1630.656199           79667.267654              1948.503884
#
#    spectral_bandwidth_var  rolloff_mean  ...  mfcc16_var  mfcc17_mean  \
# 0           117335.771563   3714.560359  ...   39.687145    -3.241280
# 1            65671.875673   3869.682242  ...   64.748276    -6.055294
# 2            75124.921716   3997.639160  ...   67.336563    -1.768610
# 3            82913.639269   3568.300218  ...   47.739452    -3.841155
# 4            60204.020268   3469.992864  ...   30.336359     0.664582
#
#    mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  \
# 0   36.488243     0.722209   38.099152    -5.050335   33.618073    -0.243027
# 1   40.677654     0.159015   51.264091    -2.837699   97.030830     5.784063
# 2   28.348579     2.378768   45.717648    -1.938424   53.050835     2.517375
# 3   28.337118     1.218588   34.770935    -3.580352   50.836224     3.630866
# 4   45.880913     1.689446   51.363583    -3.392489   26.738789     0.536961
#
#    mfcc20_var  label
# 0   43.771767  blues
# 1   59.943081  blues
# 2   33.105122  blues
# 3   32.023678  blues
# 4   29.146694  blues
#
# [5 rows x 59 columns]

# %%
# Features and Target variable
X = df.loc[:, df.columns != 'label']
y = df['label']
X.shape
# Out:
# (9990, 58)

# %%
# preprocessing
cols = X.columns
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(np_scaled, columns= cols)
X.head()
# Out:
#    length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0     0.0          0.355399         0.716757  0.293133  0.107955
# 1     0.0          0.367322         0.670347  0.253040  0.044447
# 2     0.0          0.373159         0.728067  0.296753  0.141663
# 3     0.0          0.399349         0.677066  0.298024  0.075042
# 4     0.0          0.355668         0.689113  0.322308  0.052149
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                0.262173               0.034784                 0.459205
# 1                0.270969               0.018716                 0.470831
# 2                0.265293               0.023073                 0.494051
# 3                0.238427               0.023187                 0.455246
# 4                0.233460               0.016451                 0.451651
#
#    spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean  mfcc16_var  \
# 0                0.094130      0.346153  ...     0.363613    0.056198
# 1                0.052261      0.363722  ...     0.468596    0.092912
# 2                0.059922      0.378215  ...     0.479681    0.096704
# 3                0.066234      0.329587  ...     0.386258    0.067995
# 4                0.047830      0.318453  ...     0.438567    0.042500
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0     0.397172    0.066062     0.371828    0.055344     0.380831    0.026797
# 1     0.351681    0.074001     0.362068    0.076365     0.418452    0.082414
# 2     0.420979    0.050639     0.400536    0.067509     0.433742    0.043841
# 3     0.387474    0.050617     0.380430    0.050030     0.405824    0.041898
# 4     0.460314    0.083860     0.388590    0.076524     0.409019    0.020763
#
#    mfcc20_mean  mfcc20_var
# 0     0.506746    0.047781
# 1     0.593029    0.065548
# 2     0.546264    0.036062
# 3     0.562204    0.034873
# 4     0.517913    0.031713
#
# [5 rows x 58 columns]

# %% [markdown]
# # Train and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # function to assess the best accuracy of a model

# %%
def model_assess(model, title = 'default'):
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    print('Accuracy score', title, ':', round(accuracy_score(y_test, preds), 5), '\n')

# %% [markdown]
# # model parameters

# %%
# Naive Bayes
nb = GaussianNB()
model_assess(nb, "Naive Bayes")

# Stochastic Gradient Descent
sgd = SGDClassifier(max_iter=5000, random_state=0)
model_assess(sgd, "Stochastic Gradient Descent")

# KNN
knn = KNeighborsClassifier(n_neighbors=19)
model_assess(knn, "KNN")

# Decission trees
tree = DecisionTreeClassifier()
model_assess(tree, "Decission trees")

# Random Forest
rforest = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
model_assess(rforest, "Random Forest")

# Support Vector Machine
svm = SVC(decision_function_shape="ovo")
model_assess(svm, "Support Vector Machine")

# Logistic Regression
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
model_assess(lg, "Logistic Regression")

# Neural Nets
nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5000, 10), random_state=1)
model_assess(nn, "Neural Nets")
# Out:
# Accuracy score Naive Bayes : 0.51952
#
# Accuracy score Stochastic Gradient Descent : 0.65532
#
# Accuracy score KNN : 0.80581
#
# Accuracy score Decission trees : 0.64765
#
# Accuracy score Random Forest : 0.81415
#
# Accuracy score Support Vector Machine : 0.75409
#
# Accuracy score Logistic Regression : 0.6977
#
# Accuracy score Neural Nets : 0.68135

# %%
# Cross Gradient Booster
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
model_assess(xgb, "Cross Gradient Booster")
# Out:
# Accuracy score Cross Gradient Booster : 0.88255

# %% [markdown]
# # XGBoost has the best model accuracy - 88%

# %%
# Final model
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
xgb.fit(X_train, y_train)


preds = xgb.predict(X_test)

print('Accuracy', ':', round(accuracy_score(y_test, preds), 5), '\n')

# Confusion Matrix
confusion_matr = confusion_matrix(y_test, preds) #normalize = 'true'
plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matr, cmap="Blues", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
plt.savefig("conf matrix")
# Out:
# Accuracy : 0.88255

# %%
import pickle
pickle.dump(xgb, open('xgb.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('xgb.pkl', 'rb'))
pickled_model.predict(X_test)
# Out:
# array(['hiphop', 'jazz', 'blues', ..., 'metal', 'disco', 'blues'],
#       dtype=object)

# %% [markdown]
# # Recommender system

# %%
# Libraries
import IPython.display as ipd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import preprocessing

# Read data
data = pd.read_csv(f'{general_path}/features_30_sec.csv', index_col='filename')

# Extract labels
labels = data[['label']]

# Drop labels from original dataframe
data = data.drop(columns=['length','label'])
data.head()

# Scale the data
data_scaled=preprocessing.scale(data)
print('Scaled data type:', type(data_scaled))
# Out:
# Scaled data type: <class 'numpy.ndarray'>

# %%
# Cosine similarity
similarity = cosine_similarity(data_scaled)
print("Similarity shape:", similarity.shape)

# Convert into a dataframe and then set the row index and column names as labels
sim_df_labels = pd.DataFrame(similarity)
sim_df_names = sim_df_labels.set_index(labels.index)
sim_df_names.columns = labels.index

sim_df_names.head()
# Out:
# Similarity shape: (1000, 1000)
# filename         blues.00000.wav  blues.00001.wav  blues.00002.wav  \
# filename
# blues.00000.wav         1.000000         0.049231         0.589618
# blues.00001.wav         0.049231         1.000000        -0.096834
# blues.00002.wav         0.589618        -0.096834         1.000000
# blues.00003.wav         0.284862         0.520903         0.210411
# blues.00004.wav         0.025561         0.080749         0.400266
#
# filename         blues.00003.wav  blues.00004.wav  blues.00005.wav  \
# filename
# blues.00000.wav         0.284862         0.025561        -0.346688
# blues.00001.wav         0.520903         0.080749         0.307856
# blues.00002.wav         0.210411         0.400266        -0.082019
# blues.00003.wav         1.000000         0.126437         0.134796
# blues.00004.wav         0.126437         1.000000         0.556066
#
# filename         blues.00006.wav  blues.00007.wav  blues.00008.wav  \
# filename
# blues.00000.wav        -0.219483        -0.167626         0.641877
# blues.00001.wav         0.318286         0.415258         0.120649
# blues.00002.wav        -0.028061         0.104446         0.468113
# blues.00003.wav         0.300746         0.324566         0.352758
# blues.00004.wav         0.482195         0.623455         0.029703
#
# filename         blues.00009.wav  ...  rock.00090.wav  rock.00091.wav  \
# filename                          ...
# blues.00000.wav        -0.097889  ...       -0.082829        0.546169
# blues.00001.wav         0.404168  ...       -0.098111       -0.325126
# blues.00002.wav        -0.132532  ...       -0.032408        0.561074
# blues.00003.wav         0.295184  ...       -0.320107       -0.206516
# blues.00004.wav         0.471657  ...        0.087605        0.017366
#
# filename         rock.00092.wav  rock.00093.wav  rock.00094.wav  \
# filename
# blues.00000.wav        0.578558        0.662590        0.571629
# blues.00001.wav       -0.370792       -0.191698       -0.330834
# blues.00002.wav        0.590779        0.583293        0.514537
# blues.00003.wav       -0.151132        0.041986       -0.172515
# blues.00004.wav        0.138035        0.104684       -0.034594
#
# filename         rock.00095.wav  rock.00096.wav  rock.00097.wav  \
# filename
# blues.00000.wav        0.610942        0.640835        0.496294
# blues.00001.wav       -0.077301       -0.222119       -0.302573
# blues.00002.wav        0.495707        0.566837        0.589983
# blues.00003.wav       -0.000287        0.020515       -0.107821
# blues.00004.wav        0.063454        0.063546        0.172944
#
# filename         rock.00098.wav  rock.00099.wav
# filename
# blues.00000.wav        0.284958        0.304098
# blues.00001.wav        0.499562        0.311723
# blues.00002.wav        0.216378        0.321069
# blues.00003.wav        0.502279        0.183210
# blues.00004.wav        0.153192        0.061785
#
# [5 rows x 1000 columns]

# %% [markdown]
# # function that takes the name of the song and returns top 5 best matches for that song.

# %%
def find_similar_songs(name):
    # Find songs most similar to another song
    series = sim_df_names[name].sort_values(ascending = False)
    
    # Remove cosine similarity == 1 (songs will always have the best match with themselves)
    series = series.drop(name)
    
    # Display the 5 top matches 
    print("\n*******\nSimilar songs to ", name)
    print(series.head(5))

# %%
find_similar_songs('pop.00019.wav')
# Out:
# *******
# Similar songs to  pop.00019.wav
# filename
# pop.00023.wav    0.862836
# pop.00034.wav    0.860499
# pop.00078.wav    0.829135
# pop.00088.wav    0.824456
# pop.00091.wav    0.802269
# Name: pop.00019.wav, dtype: float64

# %%
find_similar_songs('rock.00011.wav')
# Out:
# *******
# Similar songs to  rock.00011.wav
# filename
# country.00054.wav    0.600560
# jazz.00095.wav       0.593636
# jazz.00027.wav       0.554560
# jazz.00038.wav       0.544000
# jazz.00015.wav       0.530824
# Name: rock.00011.wav, dtype: float64
